# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#import tensorflow_addons as tfa
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
#warnings.filterwarnings('ignore', category=BadKey)

# %%
import keras
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Convolution2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img, array_to_img

from sklearn.metrics import roc_curve, auc, classification_report, confusion_matrix
from sklearn.metrics import precision_score, recall_score, accuracy_score
from sklearn.preprocessing import LabelEncoder
from tensorflow.python.keras import datasets, layers, models, regularizers


import glob
from tensorflow.keras.applications.imagenet_utils import preprocess_input, decode_predictions
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2
from tensorflow.keras.layers import Input

import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %%
import tensorflow_addons as tfa
from tensorflow_addons.layers import GroupNormalization

# %%
def evaluation(y, y_hat, title = 'Confusion Matrix'):
    '''takes in true values and predicted values.
    The function then prints out a classifcation report
    as well as a confusion matrix using seaborn's heatmap.'''
    cm = confusion_matrix(y, y_hat)
    precision = precision_score(y, y_hat)
    recall = recall_score(y, y_hat)
    accuracy = accuracy_score(y,y_hat)
    print(classification_report(y, y_hat, target_names=['NORMAL', 'PNEUMONIA']))
    print('Recall: ', recall)
    

    plt.plot(fpr, tpr, linestyle='-', label='InceptionResNetV2')
    #plt.plot(fpr, tpr, marker='.')
    # axis labels
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.xlim(0,1, 20)
    plt.ylim(0,1,30)
    # show the legend
    plt.legend()
    # show the plot
    plt.show()
    print('ROC-AUC:', roc_auc)
    sns.heatmap(cm,  cmap= 'Greens', annot=True, fmt='d')
    plt.xlabel('predicted')
    plt.ylabel('actual')
    plt.title(title)
    plt.show()

# %%
def show_img(train_images, train_labels):
    plt.figure(figsize=(12,12))
    for i in range(25):
        ax = plt.subplot(5,5,i+1)
        plt.imshow(train_images[i])
        if train_labels[i]:
            plt.title('PNEUMONIA')
        else:
            plt.title('NORMAL')
        plt.axis('off')

# %%
METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]

# %% [markdown]
# #### Data Generators below generate the engineered image sets that do not include train or test images with medical equipment, we still have the originial test set as well for further evaluation.

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./225)
val_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./225)
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./225)
train_data_sm = train_datagen.flow_from_directory('../data/chest_xray2/train_2/',
                                               target_size=(100,100),
                                               batch_size=32,
                                               class_mode='binary',
                                               color_mode='grayscale')
val_data_sm = val_datagen.flow_from_directory('../data/chest_xray2/val/',
                                               target_size=(100,100),
                                               batch_size=32,
                                               class_mode='binary',
                                               color_mode='grayscale')
test_data_sm = test_datagen.flow_from_directory('../data/chest_xray2/test_2/',
                                             target_size=(100,100),
                                             batch_size=32,
                                             class_mode='binary',
                                             color_mode='grayscale')
# Out:
# Found 2568 images belonging to 2 classes.
# Found 550 images belonging to 2 classes.
# Found 427 images belonging to 2 classes.

# %%
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint('2nd_model_groupnorm.h5',
                                                  save_best_only=True)
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10,
                                                    restore_best_weights=True)

# %%
model2_sm = Sequential()
model2_sm.add(Convolution2D(32, (3,3), input_shape=(100,100,1), activation='relu'))
#Group Normalization Layer
model2_sm.add(GroupNormalization(groups=2, axis=-1))
model2_sm.add(MaxPooling2D(2,2))
model2_sm.add(Flatten())
model2_sm.add(Dense(units=110, activation='relu'))
model2_sm.add(Dense(units=1, activation='sigmoid'))

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate= 1e-2,
                                                            decay_steps= 20,
                                                            decay_rate= 0.01)
optimizer = tf.keras.optimizers.SGD(learning_rate=lr_schedule)

model2_sm.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=[
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ])

history2_sm = model2_sm.fit(train_data_sm, epochs=10,  validation_data=(val_data_sm), callbacks=[checkpoint_cb, early_stopping_cb])

# %%
first_batch_sm = test_data_sm.next()
data_list = first_batch_sm[0]
batch_index = 0
class_list = first_batch_sm[1]
while batch_index <= test_data_sm.batch_index:
    data = test_data_sm.next()
    #print(data[0].shape)
    data_list=np.concatenate((data_list, data[0]))
    class_list=np.concatenate((class_list, data[1]))
    batch_index = batch_index + 1
data_array_sm = np.asarray(data_list)
data_array_sm.shape
# Out:
# (422, 100, 100, 1)

# %%
preds2_sm = model2_sm.predict_classes(data_array_sm)
evaluation(class_list, preds2_sm)

train_loss = history2_sm.history['loss']
train_acc = history2_sm.history['accuracy']
val_loss = history2_sm.history['val_loss']
val_acc = history2_sm.history['val_accuracy']


fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,5))
sns.lineplot(history2_sm.epoch, train_loss, ax=ax1, label='train_loss')
sns.lineplot(history2_sm.epoch, train_acc, ax=ax2, label='train_accuracy')

sns.lineplot(history2_sm.epoch, val_loss, ax=ax1, label='val_loss')
sns.lineplot(history2_sm.epoch, val_acc, ax=ax2, label='val_accuracy')

acc = model2_sm.evaluate_generator(test_data_sm, steps=len(test_data_sm), verbose=1)
list(zip(model2_sm.metrics_names, acc))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.61      0.45      0.52       229
#    PNEUMONIA       0.50      0.66      0.57       193
#
#     accuracy                           0.55       422
#    macro avg       0.56      0.55      0.54       422
# weighted avg       0.56      0.55      0.54       422
#
# Accurancy:  0.5450236966824644
# 86/86 [==============================] - 4s 43ms/step - loss: 0.6836 - accuracy: 0.5433 - precision: 0.5000 - recall: 0.6564
# [('loss', 0.683554470539093),
#  ('accuracy', 0.5433255434036255),
#  ('precision', 0.5),
#  ('recall', 0.656410276889801)]

# %% [markdown]
# #### New data generators to remove greys scale color mode parameter as well as add a shear range, zoom range, and horizontal flip.

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./225,
                                                               shear_range=0.3,
                                                               zoom_range=0.4,
                                                               horizontal_flip=True)
val_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./225)
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./225)
transfer_train_data = train_datagen.flow_from_directory('../data/chest_xray2/train_2/',
                                               target_size=(100,100),
                                               batch_size=32,
                                               class_mode='binary')
transfer_val_data = val_datagen.flow_from_directory('../data/chest_xray2/val/',
                                               target_size=(100,100),
                                               batch_size=32,
                                               class_mode='binary')
transfer_test_data = test_datagen.flow_from_directory('../data/chest_xray2/test_2/',
                                             target_size=(100,100),
                                             batch_size=32,
                                             class_mode='binary')
# Out:
# Found 2568 images belonging to 2 classes.
# Found 550 images belonging to 2 classes.
# Found 427 images belonging to 2 classes.

# %% [markdown]
# #### Validation data generated to evaluate the model using the data from the cell above.

# %%
transfer_first_batch = transfer_test_data.next()
transfer_data_list = transfer_first_batch[0]
batch_index = 0
transfer_class_list = transfer_first_batch[1]
while batch_index <= transfer_test_data.batch_index:
    transfer_data = transfer_test_data.next()
    #print(data[0].shape)
    transfer_data_list=np.concatenate((transfer_data_list, transfer_data[0]))
    transfer_class_list=np.concatenate((transfer_class_list, transfer_data[1]))
    batch_index = batch_index + 1
transfer_data_array = np.asarray(transfer_data_list)
transfer_data_array.shape
# Out:
# (427, 100, 100, 3)

# %% [markdown]
# #### Instantiating Inception-ResNet-V2

# %%
input_shape = Input(shape=(100,100,3))

base_model_inception_res = InceptionResNetV2(input_tensor=input_shape, include_top=False, weights='imagenet')

base_model_inception_res.trainable=False

base_model_inception_res.layers[-1].get_config()
# Out:
# {'name': 'conv_7b_ac',
#  'trainable': False,
#  'dtype': 'float32',
#  'activation': 'relu'}

# %%
tr_train_files = glob.glob('../data/chest_xray2/train_2/NORMAL/*'),  glob.glob('../data/chest_xray2/train_2/PNEUMONIA/*')

# %% [markdown]
# #### Adding class weights to the model

# %%
# NORMAL COUNT
count_normal = len(tr_train_files[0])
count_normal

# PNEUMONIA COUNT
count_pneumonia = len(tr_train_files[1])
count_pneumonia

initial_bias = np.log([count_pneumonia/count_normal])
initial_bias

weight_normal = (1 / count_normal) * (count_normal+count_pneumonia) / 2
weight_pneumonia = (1 / count_pneumonia) * (count_normal+count_pneumonia) / 2
class_weight = {0: weight_normal, 1: weight_pneumonia}
class_weight
# Out:
# {0: 1.1342756183745584, 1: 0.8941504178272981}

# %% [markdown]
# #### Adding Exponential Decay to optimizer

# %%
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=1e-2,
                                                            decay_steps=20,
                                                            decay_rate=0.01)


optimizer = tf.keras.optimizers.SGD(learning_rate=lr_schedule)

# %%
inception_resnet2 = Sequential([base_model_inception_res,
                    tf.keras.layers.GlobalAveragePooling2D(),
                    tf.keras.layers.Dense(90, activation='relu'),
                    tf.keras.layers.Dense(1, activation='sigmoid')])

inception_resnet2.compile(optimizer='Adam',
              loss='binary_crossentropy',
              metrics=METRICS)

epochs = 20
batch_size=32

steps_per_epoch = transfer_train_data.n // batch_size

inception_resnet2_history = inception_resnet2.fit(transfer_train_data, class_weight=class_weight,
                  steps_per_epoch = steps_per_epoch,
                  epochs=epochs,
                  workers=4,
                  validation_data=transfer_val_data)
# Out:
# Epoch 1/20
# 80/80 [==============================] - 27s 334ms/step - loss: 0.5749 - accuracy: 0.7603 - precision: 0.7838 - recall: 0.7273 - val_loss: 0.2175 - val_accuracy: 0.9127 - val_precision: 0.9565 - val_recall: 0.9006
# Epoch 2/20
# 80/80 [==============================] - 25s 311ms/step - loss: 0.3757 - accuracy: 0.8344 - precision: 0.8726 - recall: 0.8246 - val_loss: 0.2115 - val_accuracy: 0.9291 - val_precision: 0.9633 - val_recall: 0.9211
# Epoch 3/20
# 80/80 [==============================] - 27s 332ms/step - loss: 0.3312 - accuracy: 0.8600 - precision: 0.8926 - recall: 0.8530 - val_loss: 0.2018 - val_accuracy: 0.9236 - val_precision: 0.9310 - val_recall: 0.9474
# Epoch 4/20
# 80/80 [==============================] - 29s 366ms/step - loss: 0.3402 - accuracy: 0.8584 - precision: 0.8914 - recall: 0.8505 - val_loss: 0.2136 - val_accuracy: 0.9200 - val_precision: 0.9806 - val_recall: 0.8889
# Epoch 5/20
# 80/80 [==============================] - 28s 354ms/step - loss: 0.3123 - accuracy: 0.8659 - precision: 0.8939 - recall: 0.8623 - val_loss: 0.1911 - val_accuracy: 0.9255 - val_precision: 0.9659 - val_recall: 0.9123
# Epoch 6/20
# 80/80 [==============================] - 29s 367ms/step - loss: 0.3129 - accuracy: 0.8659 - precision: 0.8991 - recall: 0.8559 - val_loss: 0.2549 - val_accuracy: 0.9055 - val_precision: 0.9618 - val_recall: 0.8830
# Epoch 7/20
# 80/80 [==============================] - 30s 377ms/step - loss: 0.3089 - accuracy: 0.8651 - precision: 0.8939 - recall: 0.8611 - val_loss: 0.1754 - val_accuracy: 0.9364 - val_precision: 0.9694 - val_recall: 0.9269
# Epoch 8/20
# 80/80 [==============================] - 29s 360ms/step - loss: 0.3119 - accuracy: 0.8703 - precision: 0.8981 - recall: 0.8672 - val_loss: 0.1665 - val_accuracy: 0.9364 - val_precision: 0.9666 - val_recall: 0.9298
# Epoch 9/20
# 80/80 [==============================] - 29s 360ms/step - loss: 0.3051 - accuracy: 0.8722 - precision: 0.9032 - recall: 0.8637 - val_loss: 0.1663 - val_accuracy: 0.9364 - val_precision: 0.9694 - val_recall: 0.9269
# Epoch 10/20
# 80/80 [==============================] - 28s 345ms/step - loss: 0.3115 - accuracy: 0.8667 - precision: 0.9012 - recall: 0.8554 - val_loss: 0.1946 - val_accuracy: 0.9218 - val_precision: 0.9776 - val_recall: 0.8947
# Epoch 11/20
# 80/80 [==============================] - 29s 357ms/step - loss: 0.3044 - accuracy: 0.8746 - precision: 0.9016 - recall: 0.8697 - val_loss: 0.1808 - val_accuracy: 0.9345 - val_precision: 0.9752 - val_recall: 0.9181
# Epoch 12/20
# 80/80 [==============================] - 29s 363ms/step - loss: 0.2904 - accuracy: 0.8853 - precision: 0.9046 - recall: 0.8887 - val_loss: 0.1855 - val_accuracy: 0.9291 - val_precision: 0.9749 - val_recall: 0.9094
# Epoch 13/20
# 80/80 [==============================] - 29s 362ms/step - loss: 0.3136 - accuracy: 0.8730 - precision: 0.9010 - recall: 0.8679 - val_loss: 0.2106 - val_accuracy: 0.9182 - val_precision: 0.9775 - val_recall: 0.8889
# Epoch 14/20
# 80/80 [==============================] - 29s 364ms/step - loss: 0.2859 - accuracy: 0.8817 - precision: 0.9102 - recall: 0.8742 - val_loss: 0.1906 - val_accuracy: 0.9291 - val_precision: 0.9316 - val_recall: 0.9561
# Epoch 15/20
# 80/80 [==============================] - 29s 367ms/step - loss: 0.2816 - accuracy: 0.8841 - precision: 0.9152 - recall: 0.8739 - val_loss: 0.2215 - val_accuracy: 0.9127 - val_precision: 0.9804 - val_recall: 0.8772
# Epoch 16/20
# 80/80 [==============================] - 30s 371ms/step - loss: 0.2752 - accuracy: 0.8797 - precision: 0.9090 - recall: 0.8724 - val_loss: 0.2190 - val_accuracy: 0.9091 - val_precision: 0.9803 - val_recall: 0.8713
# Epoch 17/20
# 80/80 [==============================] - 29s 368ms/step - loss: 0.2830 - accuracy: 0.8876 - precision: 0.9131 - recall: 0.8828 - val_loss: 0.2510 - val_accuracy: 0.9000 - val_precision: 0.9898 - val_recall: 0.8480
# Epoch 18/20
# 80/80 [==============================] - 46s 580ms/step - loss: 0.2960 - accuracy: 0.8726 - precision: 0.9004 - recall: 0.8679 - val_loss: 0.2214 - val_accuracy: 0.9073 - val_precision: 0.9834 - val_recall: 0.8655
# Epoch 19/20
# 80/80 [==============================] - 48s 605ms/step - loss: 0.2858 - accuracy: 0.8860 - precision: 0.9205 - recall: 0.8719 - val_loss: 0.1730 - val_accuracy: 0.9345 - val_precision: 0.9693 - val_recall: 0.9240
# Epoch 20/20
# 80/80 [==============================] - 51s 635ms/step - loss: 0.2710 - accuracy: 0.8884 - precision: 0.9176 - recall: 0.8795 - val_loss: 0.2056 - val_accuracy: 0.9109 - val_precision: 0.9803 - val_recall: 0.8743

# %%
inception_resnet2_preds = inception_resnet2.predict_classes(transfer_data_array)
evaluation(transfer_class_list, inception_resnet2_preds)

train_loss = inception_resnet2_history.history['loss']
train_acc = inception_resnet2_history.history['accuracy']
val_loss = inception_resnet2_history.history['val_loss']
val_acc = inception_resnet2_history.history['val_accuracy']


fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,5))
sns.lineplot(inception_resnet2_history.epoch, train_loss, ax=ax1, label='train_loss')
sns.lineplot(inception_resnet2_history.epoch, train_acc, ax=ax2, label='train_accuracy')

sns.lineplot(inception_resnet2_history.epoch, val_loss, ax=ax1, label='val_loss')
sns.lineplot(inception_resnet2_history.epoch, val_acc, ax=ax2, label='val_accuracy')

acc = inception_resnet2.evaluate_generator(transfer_test_data, steps=len(transfer_test_data), verbose=1)
list(zip(inception_resnet2.metrics_names, acc))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.91      0.82      0.86       232
#    PNEUMONIA       0.81      0.91      0.86       195
#
#     accuracy                           0.86       427
#    macro avg       0.86      0.86      0.86       427
# weighted avg       0.87      0.86      0.86       427
#
# Accurancy:  0.8594847775175644
# 14/14 [==============================] - 12s 876ms/step - loss: 0.3999 - accuracy: 0.8595 - precision: 0.8082 - recall: 0.9077
# [('loss', 0.3999156057834625),
#  ('accuracy', 0.8594847917556763),
#  ('precision', 0.8082191944122314),
#  ('recall', 0.9076923131942749)]

# %% [markdown]
# #### Fine tuning the model beginning with layer 750

# %%
base_model_inception_res.trainable = True
print('Number of layers in the base model: ', len(base_model_inception_res.layers))

fine_tune = 750
for layer in base_model_inception_res.layers[: fine_tune]:
    layer.trainable = False

# %%
inception_resnet2.compile(optimizer='Adam',
              loss='binary_crossentropy',
              metrics=METRICS)

epochs = 20
batch_size=32

steps_per_epoch = transfer_train_data.n // batch_size

inception_resnet2_history = inception_resnet2.fit(transfer_train_data, class_weight=class_weight,
                  steps_per_epoch = steps_per_epoch,
                  epochs=epochs,
                  workers=4,
                  validation_data=transfer_val_data)
# Out:
# Epoch 1/20
# 80/80 [==============================] - 74s 929ms/step - loss: 0.4039 - accuracy: 0.8364 - precision: 0.8605 - recall: 0.8418 - val_loss: 0.8014 - val_accuracy: 0.8073 - val_precision: 0.9917 - val_recall: 0.6959
# Epoch 2/20
# 80/80 [==============================] - 66s 824ms/step - loss: 0.3318 - accuracy: 0.8616 - precision: 0.9008 - recall: 0.8456 - val_loss: 0.3745 - val_accuracy: 0.8745 - val_precision: 0.9858 - val_recall: 0.8099
# Epoch 3/20
# 80/80 [==============================] - 67s 838ms/step - loss: 0.2992 - accuracy: 0.8762 - precision: 0.9119 - recall: 0.8618 - val_loss: 0.2986 - val_accuracy: 0.9073 - val_precision: 0.9802 - val_recall: 0.8684
# Epoch 4/20
# 80/80 [==============================] - 65s 816ms/step - loss: 0.2861 - accuracy: 0.8864 - precision: 0.9123 - recall: 0.8814 - val_loss: 0.2038 - val_accuracy: 0.9218 - val_precision: 0.9838 - val_recall: 0.8889
# Epoch 5/20
# 80/80 [==============================] - 67s 831ms/step - loss: 0.2638 - accuracy: 0.8912 - precision: 0.9218 - recall: 0.8802 - val_loss: 0.1537 - val_accuracy: 0.9400 - val_precision: 0.9696 - val_recall: 0.9327
# Epoch 6/20
# 80/80 [==============================] - 66s 820ms/step - loss: 0.2530 - accuracy: 0.9046 - precision: 0.9255 - recall: 0.9020 - val_loss: 0.1816 - val_accuracy: 0.9455 - val_precision: 0.9756 - val_recall: 0.9357
# Epoch 7/20
# 80/80 [==============================] - 67s 838ms/step - loss: 0.2405 - accuracy: 0.9018 - precision: 0.9278 - recall: 0.8946 - val_loss: 0.1721 - val_accuracy: 0.9327 - val_precision: 0.9781 - val_recall: 0.9123
# Epoch 8/20
# 80/80 [==============================] - 67s 837ms/step - loss: 0.2488 - accuracy: 0.9010 - precision: 0.9392 - recall: 0.8805 - val_loss: 0.4121 - val_accuracy: 0.8673 - val_precision: 0.9786 - val_recall: 0.8041
# Epoch 9/20
# 80/80 [==============================] - 67s 839ms/step - loss: 0.2276 - accuracy: 0.9089 - precision: 0.9311 - recall: 0.9042 - val_loss: 0.1615 - val_accuracy: 0.9309 - val_precision: 0.9720 - val_recall: 0.9152
# Epoch 10/20
# 80/80 [==============================] - 52s 645ms/step - loss: 0.2417 - accuracy: 0.9054 - precision: 0.9356 - recall: 0.8920 - val_loss: 0.2438 - val_accuracy: 0.8891 - val_precision: 0.9930 - val_recall: 0.8275
# Epoch 11/20
# 80/80 [==============================] - 44s 545ms/step - loss: 0.2314 - accuracy: 0.9085 - precision: 0.9406 - recall: 0.8928 - val_loss: 0.1909 - val_accuracy: 0.9255 - val_precision: 0.9574 - val_recall: 0.9211
# Epoch 12/20
# 80/80 [==============================] - 39s 490ms/step - loss: 0.2130 - accuracy: 0.9117 - precision: 0.9466 - recall: 0.8916 - val_loss: 0.1937 - val_accuracy: 0.9109 - val_precision: 0.9835 - val_recall: 0.8713
# Epoch 13/20
# 80/80 [==============================] - 38s 481ms/step - loss: 0.2128 - accuracy: 0.9121 - precision: 0.9430 - recall: 0.8971 - val_loss: 0.3166 - val_accuracy: 0.8691 - val_precision: 0.9856 - val_recall: 0.8012
# Epoch 14/20
# 80/80 [==============================] - 39s 488ms/step - loss: 0.2143 - accuracy: 0.9136 - precision: 0.9424 - recall: 0.9005 - val_loss: 0.1539 - val_accuracy: 0.9364 - val_precision: 0.9723 - val_recall: 0.9240
# Epoch 15/20
# 80/80 [==============================] - 39s 483ms/step - loss: 0.2123 - accuracy: 0.9144 - precision: 0.9478 - recall: 0.8963 - val_loss: 0.2856 - val_accuracy: 0.8855 - val_precision: 0.9861 - val_recall: 0.8275
# Epoch 16/20
# 80/80 [==============================] - 39s 483ms/step - loss: 0.1897 - accuracy: 0.9286 - precision: 0.9491 - recall: 0.9217 - val_loss: 0.1702 - val_accuracy: 0.9345 - val_precision: 0.9581 - val_recall: 0.9357
# Epoch 17/20
# 80/80 [==============================] - 39s 481ms/step - loss: 0.1890 - accuracy: 0.9286 - precision: 0.9606 - recall: 0.9099 - val_loss: 0.2172 - val_accuracy: 0.9145 - val_precision: 0.9805 - val_recall: 0.8801
# Epoch 18/20
# 80/80 [==============================] - 38s 480ms/step - loss: 0.2090 - accuracy: 0.9219 - precision: 0.9446 - recall: 0.9140 - val_loss: 0.1703 - val_accuracy: 0.9400 - val_precision: 0.9725 - val_recall: 0.9298
# Epoch 19/20
# 80/80 [==============================] - 39s 491ms/step - loss: 0.1989 - accuracy: 0.9243 - precision: 0.9449 - recall: 0.9183 - val_loss: 0.1942 - val_accuracy: 0.9200 - val_precision: 0.9745 - val_recall: 0.8947
# Epoch 20/20
# 80/80 [==============================] - 38s 480ms/step - loss: 0.1727 - accuracy: 0.9357 - precision: 0.9523 - recall: 0.9315 - val_loss: 0.1980 - val_accuracy: 0.9218 - val_precision: 0.9716 - val_recall: 0.9006

# %%
inception_resnet2_preds = inception_resnet2.predict_classes(transfer_data_array)
evaluation(transfer_class_list, inception_resnet2_preds)

train_loss = inception_resnet2_history.history['loss']
train_acc = inception_resnet2_history.history['accuracy']
val_loss = inception_resnet2_history.history['val_loss']
val_acc = inception_resnet2_history.history['val_accuracy']


fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,5))
sns.lineplot(inception_resnet2_history.epoch, train_loss, ax=ax1, label='train_loss')
sns.lineplot(inception_resnet2_history.epoch, train_acc, ax=ax2, label='train_accuracy')

sns.lineplot(inception_resnet2_history.epoch, val_loss, ax=ax1, label='val_loss')
sns.lineplot(inception_resnet2_history.epoch, val_acc, ax=ax2, label='val_accuracy')

acc = inception_resnet2.evaluate_generator(transfer_test_data, steps=len(transfer_test_data), verbose=1)
list(zip(inception_resnet2.metrics_names, acc))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.93      0.84      0.88       232
#    PNEUMONIA       0.83      0.92      0.88       195
#
#     accuracy                           0.88       427
#    macro avg       0.88      0.88      0.88       427
# weighted avg       0.89      0.88      0.88       427
#
# Accurancy:  0.8805620608899297
# 14/14 [==============================] - 5s 368ms/step - loss: 0.3679 - accuracy: 0.8806 - precision: 0.8333 - recall: 0.9231
# [('loss', 0.3678506910800934),
#  ('accuracy', 0.8805620670318604),
#  ('precision', 0.8333333134651184),
#  ('recall', 0.9230769276618958)]

# %%
tr_train_files = glob.glob('../data/chest_xray2/val/NORMAL/*'),  glob.glob('../data/chest_xray2/val/PNEUMONIA/*')
tr_val_files = glob.glob('../data/chest_xray2/val/NORMAL/*'),  glob.glob('../data/chest_xray2/val/PNEUMONIA/*')

# %% [markdown]
# #### Adding class weights by difference in x-rays in both training and validation datasets

# %%
count_normal = len(tr_train_files[0]) + len(tr_val_files[0])
count_normal

count_pneumonia = len(tr_train_files[1]) + len(tr_val_files[1])
count_pneumonia

initial_bias = np.log([count_pneumonia/count_normal])
initial_bias
# Out:
# array([0.49727266])

# %%
weight_normal = (1 / count_normal) * (count_normal+count_pneumonia) / 2
weight_pneumonia = (1 / count_pneumonia) * (count_normal+count_pneumonia) / 2
class_weight = {0: weight_normal, 1: weight_pneumonia}
class_weight
# Out:
# {0: 1.3221153846153846, 1: 0.804093567251462}

# %%
c_back = tf.keras.callbacks.EarlyStopping(patience=13, restore_best_weights=True)

# %%
inception_resnet2.compile(optimizer='Adam',
              loss='binary_crossentropy',
              metrics=METRICS)

epochs = 50
batch_size=32

steps_per_epoch = transfer_train_data.n // batch_size

inception_resnet2_history = inception_resnet2.fit(transfer_train_data, class_weight=class_weight,
                  steps_per_epoch = steps_per_epoch,
                  epochs=epochs,
                  workers=4,
                  callbacks=c_back,
                  validation_data=transfer_val_data)
# Out:
# Epoch 1/50
# 80/80 [==============================] - 37s 460ms/step - loss: 0.1589 - accuracy: 0.9405 - precision: 0.9445 - recall: 0.9316 - val_loss: 0.2201 - val_accuracy: 0.9273 - val_precision: 0.9748 - val_recall: 0.9064
# Epoch 2/50
# 80/80 [==============================] - 35s 434ms/step - loss: 0.1600 - accuracy: 0.9416 - precision: 0.9677 - recall: 0.9269 - val_loss: 0.1902 - val_accuracy: 0.9291 - val_precision: 0.9605 - val_recall: 0.9240
# Epoch 3/50
# 80/80 [==============================] - 38s 474ms/step - loss: 0.1591 - accuracy: 0.9393 - precision: 0.9619 - recall: 0.9280 - val_loss: 0.2304 - val_accuracy: 0.9273 - val_precision: 0.9548 - val_recall: 0.9269
# Epoch 4/50
# 80/80 [==============================] - 38s 470ms/step - loss: 0.1462 - accuracy: 0.9436 - precision: 0.9576 - recall: 0.9408 - val_loss: 0.1692 - val_accuracy: 0.9418 - val_precision: 0.9697 - val_recall: 0.9357
# Epoch 5/50
# 80/80 [==============================] - 37s 463ms/step - loss: 0.1425 - accuracy: 0.9472 - precision: 0.9693 - recall: 0.9350 - val_loss: 0.2731 - val_accuracy: 0.9236 - val_precision: 0.9412 - val_recall: 0.9357
# Epoch 6/50
# 80/80 [==============================] - 37s 465ms/step - loss: 0.1482 - accuracy: 0.9440 - precision: 0.9711 - recall: 0.9272 - val_loss: 0.3200 - val_accuracy: 0.8982 - val_precision: 0.9831 - val_recall: 0.8509
# Epoch 7/50
# 80/80 [==============================] - 37s 461ms/step - loss: 0.1424 - accuracy: 0.9444 - precision: 0.9657 - recall: 0.9336 - val_loss: 0.2052 - val_accuracy: 0.9255 - val_precision: 0.9574 - val_recall: 0.9211
# Epoch 8/50
# 80/80 [==============================] - 37s 467ms/step - loss: 0.1640 - accuracy: 0.9377 - precision: 0.9607 - recall: 0.9269 - val_loss: 0.2640 - val_accuracy: 0.9164 - val_precision: 0.9966 - val_recall: 0.8684
# Epoch 9/50
# 80/80 [==============================] - 37s 464ms/step - loss: 0.1460 - accuracy: 0.9412 - precision: 0.9628 - recall: 0.9309 - val_loss: 0.2407 - val_accuracy: 0.9236 - val_precision: 0.9839 - val_recall: 0.8918
# Epoch 10/50
# 80/80 [==============================] - 38s 473ms/step - loss: 0.1456 - accuracy: 0.9479 - precision: 0.9694 - recall: 0.9367 - val_loss: 0.2945 - val_accuracy: 0.9073 - val_precision: 0.9966 - val_recall: 0.8538
# Epoch 11/50
# 80/80 [==============================] - 37s 464ms/step - loss: 0.1501 - accuracy: 0.9460 - precision: 0.9646 - recall: 0.9381 - val_loss: 0.1889 - val_accuracy: 0.9273 - val_precision: 0.9390 - val_recall: 0.9444
# Epoch 12/50
# 80/80 [==============================] - 37s 468ms/step - loss: 0.1573 - accuracy: 0.9412 - precision: 0.9643 - recall: 0.9298 - val_loss: 0.1984 - val_accuracy: 0.9291 - val_precision: 0.9871 - val_recall: 0.8977
# Epoch 13/50
# 80/80 [==============================] - 38s 472ms/step - loss: 0.1459 - accuracy: 0.9479 - precision: 0.9601 - recall: 0.9466 - val_loss: 0.1850 - val_accuracy: 0.9309 - val_precision: 0.9663 - val_recall: 0.9211
# Epoch 14/50
# 80/80 [==============================] - 38s 471ms/step - loss: 0.1477 - accuracy: 0.9456 - precision: 0.9672 - recall: 0.9345 - val_loss: 0.3269 - val_accuracy: 0.8891 - val_precision: 0.9930 - val_recall: 0.8275
# Epoch 15/50
# 80/80 [==============================] - 39s 485ms/step - loss: 0.1439 - accuracy: 0.9472 - precision: 0.9613 - recall: 0.9437 - val_loss: 0.2650 - val_accuracy: 0.9109 - val_precision: 0.9933 - val_recall: 0.8626
# Epoch 16/50
# 80/80 [==============================] - 39s 484ms/step - loss: 0.1344 - accuracy: 0.9468 - precision: 0.9665 - recall: 0.9372 - val_loss: 0.2004 - val_accuracy: 0.9327 - val_precision: 0.9841 - val_recall: 0.9064

# %%
inception_resnet2_preds = inception_resnet2.predict_classes(transfer_data_array)
evaluation(transfer_class_list, inception_resnet2_preds)

train_loss = inception_resnet2_history.history['loss']
train_acc = inception_resnet2_history.history['accuracy']
val_loss = inception_resnet2_history.history['val_loss']
val_acc = inception_resnet2_history.history['val_accuracy']


fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,5))
sns.lineplot(inception_resnet2_history.epoch, train_loss, ax=ax1, label='train_loss')
sns.lineplot(inception_resnet2_history.epoch, train_acc, ax=ax2, label='train_accuracy')

sns.lineplot(inception_resnet2_history.epoch, val_loss, ax=ax1, label='val_loss')
sns.lineplot(inception_resnet2_history.epoch, val_acc, ax=ax2, label='val_accuracy')

acc = inception_resnet2.evaluate_generator(transfer_test_data, steps=len(transfer_test_data), verbose=1)
list(zip(inception_resnet2.metrics_names, acc))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.95      0.84      0.89       232
#    PNEUMONIA       0.84      0.94      0.89       195
#
#     accuracy                           0.89       427
#    macro avg       0.89      0.89      0.89       427
# weighted avg       0.90      0.89      0.89       427
#
# Accurancy:  0.8899297423887588
# 14/14 [==============================] - 5s 356ms/step - loss: 0.3626 - accuracy: 0.8899 - precision: 0.8364 - recall: 0.9436
# [('loss', 0.36264967918395996),
#  ('accuracy', 0.8899297714233398),
#  ('precision', 0.8363636136054993),
#  ('recall', 0.9435897469520569)]

# %%
mets = list(zip(inception_resnet2.metrics_names, acc))

# %%
fig, ax = plt.subplots(1, 3, figsize=(20, 5))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy']):
    ax[i].plot(inception_resnet2_history.history[met])
    ax[i].plot(inception_resnet2_history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].set_ylim(0.5,1)
    ax[i].legend(['train', 'val'])

# %%
from sklearn.metrics import roc_curve, auc

# %%
fpr, tpr, thresholds = roc_curve(transfer_class_list, inception_resnet2_preds)
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, linestyle='--', label='InceptionResNetV2')
#plt.plot(fpr, tpr, marker='.')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.xlim(0,1, 20)
plt.ylim(0,1,30)
# show the legend
plt.legend()
# show the plot
plt.show()

# %%
roc_auc
# Out:
# 0.8942086648983201

# %% [markdown]
# #### Fine tuning the model beginning with layer 600

# %%
base_model_inception_res.trainable = True
print('Number of layers in the base model: ', len(base_model_inception_res.layers))

fine_tune = 600
for layer in base_model_inception_res.layers[: fine_tune]:
    layer.trainable = False
# Out:
# Number of layers in the base model:  780

# %%
inception_resnet2.compile(optimizer='Adam',
              loss='binary_crossentropy',
              metrics=METRICS)

epochs = 50
batch_size=32

steps_per_epoch = transfer_train_data.n // batch_size

inception_resnet2_history = inception_resnet2.fit(transfer_train_data, class_weight=class_weight,
                  steps_per_epoch = steps_per_epoch,
                  epochs=epochs,
                  workers=4,
                  callbacks=c_back,
                  validation_data=transfer_val_data)
# Out:
# Epoch 1/50
# 80/80 [==============================] - 43s 540ms/step - loss: 0.2044 - accuracy: 0.9203 - precision: 0.9330 - recall: 0.9300 - val_loss: 1.8418 - val_accuracy: 0.9491 - val_precision: 0.9816 - val_recall: 0.9357
# Epoch 2/50
# 80/80 [==============================] - 41s 519ms/step - loss: 0.1628 - accuracy: 0.9322 - precision: 0.9476 - recall: 0.9303 - val_loss: 0.2431 - val_accuracy: 0.9127 - val_precision: 0.9868 - val_recall: 0.8713
# Epoch 3/50
# 80/80 [==============================] - 42s 528ms/step - loss: 0.1770 - accuracy: 0.9298 - precision: 0.9395 - recall: 0.9342 - val_loss: 0.2322 - val_accuracy: 0.9000 - val_precision: 0.9898 - val_recall: 0.8480
# Epoch 4/50
# 80/80 [==============================] - 44s 548ms/step - loss: 0.1919 - accuracy: 0.9243 - precision: 0.9310 - recall: 0.9337 - val_loss: 0.1837 - val_accuracy: 0.9400 - val_precision: 0.9874 - val_recall: 0.9152
# Epoch 5/50
# 80/80 [==============================] - 42s 526ms/step - loss: 0.1895 - accuracy: 0.9105 - precision: 0.9180 - recall: 0.9225 - val_loss: 0.2031 - val_accuracy: 0.9218 - val_precision: 0.9934 - val_recall: 0.8801
# Epoch 6/50
# 80/80 [==============================] - 42s 522ms/step - loss: 0.1792 - accuracy: 0.9156 - precision: 0.9208 - recall: 0.9298 - val_loss: 0.1847 - val_accuracy: 0.9255 - val_precision: 0.9902 - val_recall: 0.8889
# Epoch 7/50
# 80/80 [==============================] - 42s 522ms/step - loss: 0.1995 - accuracy: 0.9144 - precision: 0.9325 - recall: 0.9135 - val_loss: 0.3176 - val_accuracy: 0.8982 - val_precision: 0.9965 - val_recall: 0.8392
# Epoch 8/50
# 80/80 [==============================] - 42s 524ms/step - loss: 0.1796 - accuracy: 0.9361 - precision: 0.9625 - recall: 0.9218 - val_loss: 0.2803 - val_accuracy: 0.8691 - val_precision: 1.0000 - val_recall: 0.7895
# Epoch 9/50
# 80/80 [==============================] - 43s 532ms/step - loss: 0.1607 - accuracy: 0.9385 - precision: 0.9716 - recall: 0.9167 - val_loss: 0.1885 - val_accuracy: 0.9273 - val_precision: 0.9967 - val_recall: 0.8860
# Epoch 10/50
# 80/80 [==============================] - 42s 527ms/step - loss: 0.1623 - accuracy: 0.9338 - precision: 0.9757 - recall: 0.9044 - val_loss: 0.1619 - val_accuracy: 0.9382 - val_precision: 0.9904 - val_recall: 0.9094
# Epoch 11/50
# 80/80 [==============================] - 42s 521ms/step - loss: 0.1564 - accuracy: 0.9377 - precision: 0.9701 - recall: 0.9167 - val_loss: 0.1528 - val_accuracy: 0.9418 - val_precision: 0.9905 - val_recall: 0.9152
# Epoch 12/50
# 80/80 [==============================] - 42s 522ms/step - loss: 0.1673 - accuracy: 0.9334 - precision: 0.9713 - recall: 0.9076 - val_loss: 0.2561 - val_accuracy: 0.8745 - val_precision: 1.0000 - val_recall: 0.7982
# Epoch 13/50
# 80/80 [==============================] - 42s 522ms/step - loss: 0.1858 - accuracy: 0.9271 - precision: 0.9639 - recall: 0.9034 - val_loss: 0.1983 - val_accuracy: 0.9327 - val_precision: 0.9967 - val_recall: 0.8947
# Epoch 14/50
# 80/80 [==============================] - 43s 532ms/step - loss: 0.1464 - accuracy: 0.9412 - precision: 0.9725 - recall: 0.9212 - val_loss: 0.2411 - val_accuracy: 0.9000 - val_precision: 1.0000 - val_recall: 0.8392
# Epoch 15/50
# 80/80 [==============================] - 42s 526ms/step - loss: 0.1581 - accuracy: 0.9357 - precision: 0.9722 - recall: 0.9113 - val_loss: 0.2329 - val_accuracy: 0.8982 - val_precision: 0.9965 - val_recall: 0.8392
# Epoch 16/50
# 80/80 [==============================] - 42s 531ms/step - loss: 0.1588 - accuracy: 0.9357 - precision: 0.9708 - recall: 0.9126 - val_loss: 0.1500 - val_accuracy: 0.9400 - val_precision: 0.9936 - val_recall: 0.9094
# Epoch 17/50
# 80/80 [==============================] - 42s 528ms/step - loss: 0.1601 - accuracy: 0.9389 - precision: 0.9731 - recall: 0.9163 - val_loss: 0.1843 - val_accuracy: 0.9309 - val_precision: 0.9903 - val_recall: 0.8977
# Epoch 18/50
# 80/80 [==============================] - 42s 525ms/step - loss: 0.1739 - accuracy: 0.9349 - precision: 0.9589 - recall: 0.9230 - val_loss: 0.1729 - val_accuracy: 0.9364 - val_precision: 0.9873 - val_recall: 0.9094
# Epoch 19/50
# 80/80 [==============================] - 42s 531ms/step - loss: 0.1799 - accuracy: 0.9405 - precision: 0.9724 - recall: 0.9195 - val_loss: 0.4129 - val_accuracy: 0.8182 - val_precision: 1.0000 - val_recall: 0.7076
# Epoch 20/50
# 80/80 [==============================] - 42s 529ms/step - loss: 0.1706 - accuracy: 0.9361 - precision: 0.9721 - recall: 0.9117 - val_loss: 0.2211 - val_accuracy: 0.9091 - val_precision: 0.9966 - val_recall: 0.8567
# Epoch 21/50
# 80/80 [==============================] - 42s 530ms/step - loss: 0.1734 - accuracy: 0.9440 - precision: 0.9677 - recall: 0.9309 - val_loss: 0.2139 - val_accuracy: 0.9109 - val_precision: 0.9933 - val_recall: 0.8626
# Epoch 22/50
# 80/80 [==============================] - 42s 531ms/step - loss: 0.1815 - accuracy: 0.9409 - precision: 0.9580 - recall: 0.9350 - val_loss: 0.2463 - val_accuracy: 0.9073 - val_precision: 1.0000 - val_recall: 0.8509
# Epoch 23/50
# 80/80 [==============================] - 43s 535ms/step - loss: 0.1751 - accuracy: 0.9322 - precision: 0.9650 - recall: 0.9119 - val_loss: 0.1858 - val_accuracy: 0.9273 - val_precision: 0.9935 - val_recall: 0.8889
# Epoch 24/50
# 80/80 [==============================] - 43s 536ms/step - loss: 0.1763 - accuracy: 0.9330 - precision: 0.9635 - recall: 0.9145 - val_loss: 0.2601 - val_accuracy: 0.8945 - val_precision: 1.0000 - val_recall: 0.8304
# Epoch 25/50
# 80/80 [==============================] - 43s 532ms/step - loss: 0.1724 - accuracy: 0.9357 - precision: 0.9652 - recall: 0.9183 - val_loss: 0.2676 - val_accuracy: 0.8745 - val_precision: 0.9964 - val_recall: 0.8012
# Epoch 26/50
# 80/80 [==============================] - 43s 535ms/step - loss: 0.1642 - accuracy: 0.9389 - precision: 0.9676 - recall: 0.9220 - val_loss: 0.2359 - val_accuracy: 0.9000 - val_precision: 1.0000 - val_recall: 0.8392
# Epoch 27/50
# 80/80 [==============================] - 43s 535ms/step - loss: 0.1728 - accuracy: 0.9409 - precision: 0.9667 - recall: 0.9257 - val_loss: 0.1541 - val_accuracy: 0.9382 - val_precision: 0.9904 - val_recall: 0.9094
# Epoch 28/50
# 80/80 [==============================] - 43s 535ms/step - loss: 0.1547 - accuracy: 0.9416 - precision: 0.9622 - recall: 0.9324 - val_loss: 0.2122 - val_accuracy: 0.9145 - val_precision: 1.0000 - val_recall: 0.8626
# Epoch 29/50
# 80/80 [==============================] - 44s 547ms/step - loss: 0.1586 - accuracy: 0.9440 - precision: 0.9671 - recall: 0.9316 - val_loss: 0.1562 - val_accuracy: 0.9364 - val_precision: 0.9904 - val_recall: 0.9064
# Epoch 30/50
# 80/80 [==============================] - 44s 549ms/step - loss: 0.1629 - accuracy: 0.9412 - precision: 0.9696 - recall: 0.9237 - val_loss: 0.2209 - val_accuracy: 0.9127 - val_precision: 1.0000 - val_recall: 0.8596

# %%
inception_resnet2_preds = inception_resnet2.predict_classes(transfer_data_array)
evaluation(transfer_class_list, inception_resnet2_preds)

train_loss = inception_resnet2_history.history['loss']
train_acc = inception_resnet2_history.history['accuracy']
val_loss = inception_resnet2_history.history['val_loss']
val_acc = inception_resnet2_history.history['val_accuracy']


fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,5))
sns.lineplot(inception_resnet2_history.epoch, train_loss, ax=ax1, label='train_loss')
sns.lineplot(inception_resnet2_history.epoch, train_acc, ax=ax2, label='train_accuracy')

sns.lineplot(inception_resnet2_history.epoch, val_loss, ax=ax1, label='val_loss')
sns.lineplot(inception_resnet2_history.epoch, val_acc, ax=ax2, label='val_accuracy')

acc = inception_resnet2.evaluate_generator(transfer_test_data, steps=len(transfer_test_data), verbose=1)
list(zip(inception_resnet2.metrics_names, acc))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.96      0.88      0.91       232
#    PNEUMONIA       0.87      0.95      0.91       195
#
#     accuracy                           0.91       427
#    macro avg       0.91      0.91      0.91       427
# weighted avg       0.92      0.91      0.91       427
#
# Accurancy:  0.9110070257611241
# 14/14 [==============================] - 5s 391ms/step - loss: 0.2780 - accuracy: 0.9110 - precision: 0.8651 - recall: 0.9538
# [('loss', 0.2779882550239563),
#  ('accuracy', 0.9110070466995239),
#  ('precision', 0.8651162981987),
#  ('recall', 0.9538461565971375)]

# %% [markdown]
# #### Adding early callback to focus on recall score

# %%
c_back = tf.keras.callbacks.EarlyStopping(patience=16, restore_best_weights=True, monitor='recall')

# %%
inception_resnet2.compile(optimizer='Adam',
              loss='binary_crossentropy',
              metrics=METRICS)

epochs = 50
batch_size=32

steps_per_epoch = transfer_train_data.n // batch_size

inception_resnet2_history = inception_resnet2.fit(transfer_train_data, class_weight=class_weight,
                  steps_per_epoch = steps_per_epoch,
                  epochs=epochs,
                  workers=4,
                  callbacks=c_back,
                  validation_data=transfer_val_data)
# Out:
# Epoch 1/50
# 80/80 [==============================] - 43s 535ms/step - loss: 0.1733 - accuracy: 0.9267 - precision: 0.9560 - recall: 0.9027 - val_loss: 0.3019 - val_accuracy: 0.8636 - val_precision: 1.0000 - val_recall: 0.7807
# Epoch 2/50
# 80/80 [==============================] - 41s 518ms/step - loss: 0.1701 - accuracy: 0.9251 - precision: 0.9637 - recall: 0.8998 - val_loss: 0.2379 - val_accuracy: 0.8964 - val_precision: 1.0000 - val_recall: 0.8333
# Epoch 3/50
# 80/80 [==============================] - 42s 523ms/step - loss: 0.1640 - accuracy: 0.9361 - precision: 0.9673 - recall: 0.9169 - val_loss: 0.1518 - val_accuracy: 0.9491 - val_precision: 0.9906 - val_recall: 0.9269
# Epoch 4/50
# 80/80 [==============================] - 43s 532ms/step - loss: 0.1639 - accuracy: 0.9409 - precision: 0.9681 - recall: 0.9243 - val_loss: 0.1829 - val_accuracy: 0.9309 - val_precision: 0.9935 - val_recall: 0.8947
# Epoch 5/50
# 80/80 [==============================] - 42s 530ms/step - loss: 0.1739 - accuracy: 0.9353 - precision: 0.9686 - recall: 0.9140 - val_loss: 0.2446 - val_accuracy: 0.9018 - val_precision: 1.0000 - val_recall: 0.8421
# Epoch 6/50
# 80/80 [==============================] - 43s 540ms/step - loss: 0.1538 - accuracy: 0.9487 - precision: 0.9693 - recall: 0.9378 - val_loss: 0.2955 - val_accuracy: 0.8636 - val_precision: 1.0000 - val_recall: 0.7807
# Epoch 7/50
# 80/80 [==============================] - 44s 552ms/step - loss: 0.1753 - accuracy: 0.9377 - precision: 0.9640 - recall: 0.9234 - val_loss: 0.1883 - val_accuracy: 0.9309 - val_precision: 0.9935 - val_recall: 0.8947
# Epoch 8/50
# 80/80 [==============================] - 44s 545ms/step - loss: 0.1346 - accuracy: 0.9416 - precision: 0.9705 - recall: 0.9241 - val_loss: 0.1476 - val_accuracy: 0.9473 - val_precision: 0.9906 - val_recall: 0.9240
# Epoch 9/50
# 80/80 [==============================] - 44s 545ms/step - loss: 0.1310 - accuracy: 0.9500 - precision: 0.9683 - recall: 0.9413 - val_loss: 0.1570 - val_accuracy: 0.9400 - val_precision: 0.9905 - val_recall: 0.9123
# Epoch 10/50
# 80/80 [==============================] - 43s 542ms/step - loss: 0.1390 - accuracy: 0.9452 - precision: 0.9693 - recall: 0.9318 - val_loss: 0.2602 - val_accuracy: 0.8818 - val_precision: 1.0000 - val_recall: 0.8099
# Epoch 11/50
# 80/80 [==============================] - 43s 541ms/step - loss: 0.1439 - accuracy: 0.9409 - precision: 0.9677 - recall: 0.9255 - val_loss: 0.1894 - val_accuracy: 0.9273 - val_precision: 0.9935 - val_recall: 0.8889
# Epoch 12/50
# 80/80 [==============================] - 43s 539ms/step - loss: 0.1414 - accuracy: 0.9444 - precision: 0.9726 - recall: 0.9267 - val_loss: 0.1571 - val_accuracy: 0.9455 - val_precision: 0.9906 - val_recall: 0.9211
# Epoch 13/50
# 80/80 [==============================] - 43s 539ms/step - loss: 0.1412 - accuracy: 0.9515 - precision: 0.9690 - recall: 0.9437 - val_loss: 0.1811 - val_accuracy: 0.9327 - val_precision: 0.9872 - val_recall: 0.9035
# Epoch 14/50
# 80/80 [==============================] - 43s 540ms/step - loss: 0.1641 - accuracy: 0.9353 - precision: 0.9610 - recall: 0.9216 - val_loss: 0.1788 - val_accuracy: 0.9291 - val_precision: 0.9903 - val_recall: 0.8947
# Epoch 15/50
# 80/80 [==============================] - 43s 541ms/step - loss: 0.1493 - accuracy: 0.9464 - precision: 0.9626 - recall: 0.9409 - val_loss: 0.1538 - val_accuracy: 0.9491 - val_precision: 0.9876 - val_recall: 0.9298
# Epoch 16/50
# 80/80 [==============================] - 43s 542ms/step - loss: 0.1483 - accuracy: 0.9448 - precision: 0.9692 - recall: 0.9309 - val_loss: 0.2122 - val_accuracy: 0.9091 - val_precision: 0.9966 - val_recall: 0.8567
# Epoch 17/50
# 80/80 [==============================] - 43s 539ms/step - loss: 0.1418 - accuracy: 0.9444 - precision: 0.9692 - recall: 0.9303 - val_loss: 0.2491 - val_accuracy: 0.9055 - val_precision: 0.9966 - val_recall: 0.8509
# Epoch 18/50
# 80/80 [==============================] - 44s 545ms/step - loss: 0.1366 - accuracy: 0.9479 - precision: 0.9673 - recall: 0.9387 - val_loss: 0.1275 - val_accuracy: 0.9582 - val_precision: 0.9790 - val_recall: 0.9532

# %%
inception_resnet2_preds = inception_resnet2.predict_classes(transfer_data_array)
evaluation(transfer_class_list, inception_resnet2_preds)

train_loss = inception_resnet2_history.history['loss']
train_acc = inception_resnet2_history.history['accuracy']
val_loss = inception_resnet2_history.history['val_loss']
val_acc = inception_resnet2_history.history['val_accuracy']


fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,5))
sns.lineplot(inception_resnet2_history.epoch, train_loss, ax=ax1, label='train_loss')
sns.lineplot(inception_resnet2_history.epoch, train_acc, ax=ax2, label='train_accuracy')

sns.lineplot(inception_resnet2_history.epoch, val_loss, ax=ax1, label='val_loss')
sns.lineplot(inception_resnet2_history.epoch, val_acc, ax=ax2, label='val_accuracy')

acc = inception_resnet2.evaluate_generator(transfer_test_data, steps=len(transfer_test_data), verbose=1)
list(zip(inception_resnet2.metrics_names, acc))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.91      0.90      0.90       232
#    PNEUMONIA       0.88      0.89      0.89       195
#
#     accuracy                           0.89       427
#    macro avg       0.89      0.89      0.89       427
# weighted avg       0.89      0.89      0.89       427
#
# Accurancy:  0.8946135831381733
# 14/14 [==============================] - 5s 374ms/step - loss: 0.4218 - accuracy: 0.8946 - precision: 0.8788 - recall: 0.8923
# [('loss', 0.42184752225875854),
#  ('accuracy', 0.8946135640144348),
#  ('precision', 0.8787878751754761),
#  ('recall', 0.892307698726654)]

# %% [markdown]
# #### Fine Tuning iteration from layer 635

# %%
base_model_inception_res.trainable = True
print('Number of layers in the base model: ', len(base_model_inception_res.layers))

fine_tune = 635
for layer in base_model_inception_res.layers[: fine_tune]:
    layer.trainable = False
# Out:
# Number of layers in the base model:  780

# %%
c_back = tf.keras.callbacks.EarlyStopping(patience=16, restore_best_weights=True)

# %%
inception_resnet2.compile(optimizer='Adam',
              loss='binary_crossentropy',
              metrics=METRICS)

epochs = 50
batch_size=32

steps_per_epoch = transfer_train_data.n // batch_size

inception_resnet2_history = inception_resnet2.fit(transfer_train_data, class_weight=class_weight,
                  steps_per_epoch = steps_per_epoch,
                  epochs=epochs,
                  workers=4,
                  callbacks=c_back,
                  validation_data=transfer_val_data)
# Out:
# Epoch 1/50
# 80/80 [==============================] - 42s 520ms/step - loss: 0.1680 - accuracy: 0.9314 - precision: 0.9604 - recall: 0.9015 - val_loss: 0.1686 - val_accuracy: 0.9345 - val_precision: 0.9935 - val_recall: 0.9006
# Epoch 2/50
# 80/80 [==============================] - 40s 496ms/step - loss: 0.1687 - accuracy: 0.9326 - precision: 0.9636 - recall: 0.9141 - val_loss: 0.2215 - val_accuracy: 0.9091 - val_precision: 0.9966 - val_recall: 0.8567
# Epoch 3/50
# 80/80 [==============================] - 41s 515ms/step - loss: 0.1719 - accuracy: 0.9345 - precision: 0.9624 - recall: 0.9191 - val_loss: 0.2054 - val_accuracy: 0.9273 - val_precision: 0.9935 - val_recall: 0.8889
# Epoch 4/50
# 80/80 [==============================] - 41s 510ms/step - loss: 0.1506 - accuracy: 0.9412 - precision: 0.9681 - recall: 0.9250 - val_loss: 0.1730 - val_accuracy: 0.9491 - val_precision: 0.9876 - val_recall: 0.9298
# Epoch 5/50
# 80/80 [==============================] - 41s 507ms/step - loss: 0.1901 - accuracy: 0.9164 - precision: 0.9568 - recall: 0.8905 - val_loss: 0.3677 - val_accuracy: 0.8418 - val_precision: 1.0000 - val_recall: 0.7456
# Epoch 6/50
# 80/80 [==============================] - 40s 502ms/step - loss: 0.1815 - accuracy: 0.9192 - precision: 0.9625 - recall: 0.8897 - val_loss: 0.4209 - val_accuracy: 0.8182 - val_precision: 1.0000 - val_recall: 0.7076
# Epoch 7/50
# 80/80 [==============================] - 40s 506ms/step - loss: 0.1803 - accuracy: 0.9298 - precision: 0.9571 - recall: 0.9151 - val_loss: 0.2191 - val_accuracy: 0.9255 - val_precision: 0.9967 - val_recall: 0.8830
# Epoch 8/50
# 80/80 [==============================] - 41s 508ms/step - loss: 0.2049 - accuracy: 0.8967 - precision: 0.9543 - recall: 0.8559 - val_loss: 0.3482 - val_accuracy: 0.8527 - val_precision: 1.0000 - val_recall: 0.7632
# Epoch 9/50
# 80/80 [==============================] - 41s 508ms/step - loss: 0.1684 - accuracy: 0.9258 - precision: 0.9593 - recall: 0.9056 - val_loss: 0.2363 - val_accuracy: 0.9127 - val_precision: 0.9966 - val_recall: 0.8626
# Epoch 10/50
# 80/80 [==============================] - 40s 502ms/step - loss: 0.1701 - accuracy: 0.9188 - precision: 0.9698 - recall: 0.8822 - val_loss: 0.2426 - val_accuracy: 0.8982 - val_precision: 1.0000 - val_recall: 0.8363
# Epoch 11/50
# 80/80 [==============================] - 41s 508ms/step - loss: 0.1730 - accuracy: 0.9227 - precision: 0.9587 - recall: 0.9006 - val_loss: 0.1817 - val_accuracy: 0.9436 - val_precision: 0.9937 - val_recall: 0.9152
# Epoch 12/50
# 80/80 [==============================] - 41s 507ms/step - loss: 0.1714 - accuracy: 0.9164 - precision: 0.9590 - recall: 0.8888 - val_loss: 0.2882 - val_accuracy: 0.8636 - val_precision: 1.0000 - val_recall: 0.7807
# Epoch 13/50
# 80/80 [==============================] - 41s 509ms/step - loss: 0.1745 - accuracy: 0.9263 - precision: 0.9695 - recall: 0.8963 - val_loss: 0.1363 - val_accuracy: 0.9564 - val_precision: 0.9877 - val_recall: 0.9415
# Epoch 14/50
# 80/80 [==============================] - 40s 504ms/step - loss: 0.1617 - accuracy: 0.9314 - precision: 0.9698 - recall: 0.9056 - val_loss: 0.1964 - val_accuracy: 0.9200 - val_precision: 0.9934 - val_recall: 0.8772
# Epoch 15/50
# 80/80 [==============================] - 41s 510ms/step - loss: 0.1424 - accuracy: 0.9405 - precision: 0.9788 - recall: 0.9131 - val_loss: 0.2675 - val_accuracy: 0.8855 - val_precision: 1.0000 - val_recall: 0.8158
# Epoch 16/50
# 80/80 [==============================] - 41s 510ms/step - loss: 0.1770 - accuracy: 0.9168 - precision: 0.9646 - recall: 0.8836 - val_loss: 0.1795 - val_accuracy: 0.9364 - val_precision: 0.9936 - val_recall: 0.9035
# Epoch 17/50
# 80/80 [==============================] - 41s 517ms/step - loss: 0.1586 - accuracy: 0.9211 - precision: 0.9665 - recall: 0.8905 - val_loss: 0.1762 - val_accuracy: 0.9382 - val_precision: 0.9936 - val_recall: 0.9064
# Epoch 18/50
# 80/80 [==============================] - 41s 512ms/step - loss: 0.1610 - accuracy: 0.9251 - precision: 0.9659 - recall: 0.8978 - val_loss: 0.2152 - val_accuracy: 0.9182 - val_precision: 0.9967 - val_recall: 0.8713
# Epoch 19/50
# 80/80 [==============================] - 41s 508ms/step - loss: 0.1648 - accuracy: 0.9310 - precision: 0.9600 - recall: 0.9147 - val_loss: 0.2112 - val_accuracy: 0.9145 - val_precision: 0.9966 - val_recall: 0.8655
# Epoch 20/50
# 80/80 [==============================] - 41s 508ms/step - loss: 0.1501 - accuracy: 0.9243 - precision: 0.9694 - recall: 0.8928 - val_loss: 0.1893 - val_accuracy: 0.9309 - val_precision: 0.9935 - val_recall: 0.8947
# Epoch 21/50
# 80/80 [==============================] - 41s 512ms/step - loss: 0.1584 - accuracy: 0.9290 - precision: 0.9660 - recall: 0.9046 - val_loss: 0.2091 - val_accuracy: 0.9127 - val_precision: 0.9966 - val_recall: 0.8626
# Epoch 22/50
# 80/80 [==============================] - 41s 510ms/step - loss: 0.1709 - accuracy: 0.9101 - precision: 0.9633 - recall: 0.8720 - val_loss: 0.2753 - val_accuracy: 0.8782 - val_precision: 1.0000 - val_recall: 0.8041
# Epoch 23/50
# 80/80 [==============================] - 41s 511ms/step - loss: 0.1453 - accuracy: 0.9290 - precision: 0.9724 - recall: 0.8982 - val_loss: 0.1921 - val_accuracy: 0.9218 - val_precision: 0.9934 - val_recall: 0.8801
# Epoch 24/50
# 80/80 [==============================] - 41s 509ms/step - loss: 0.1687 - accuracy: 0.9152 - precision: 0.9674 - recall: 0.8782 - val_loss: 0.2312 - val_accuracy: 0.9091 - val_precision: 1.0000 - val_recall: 0.8538
# Epoch 25/50
# 80/80 [==============================] - 41s 510ms/step - loss: 0.1602 - accuracy: 0.9200 - precision: 0.9656 - recall: 0.8890 - val_loss: 0.2198 - val_accuracy: 0.9164 - val_precision: 1.0000 - val_recall: 0.8655
# Epoch 26/50
# 80/80 [==============================] - 41s 510ms/step - loss: 0.1696 - accuracy: 0.9243 - precision: 0.9651 - recall: 0.8971 - val_loss: 0.2833 - val_accuracy: 0.8891 - val_precision: 0.9965 - val_recall: 0.8246
# Epoch 27/50
# 80/80 [==============================] - 42s 524ms/step - loss: 0.1530 - accuracy: 0.9267 - precision: 0.9639 - recall: 0.9029 - val_loss: 0.2069 - val_accuracy: 0.9291 - val_precision: 0.9935 - val_recall: 0.8918
# Epoch 28/50
# 80/80 [==============================] - 41s 513ms/step - loss: 0.1500 - accuracy: 0.9267 - precision: 0.9632 - recall: 0.9034 - val_loss: 0.1676 - val_accuracy: 0.9382 - val_precision: 0.9873 - val_recall: 0.9123
# Epoch 29/50
# 80/80 [==============================] - 41s 513ms/step - loss: 0.1532 - accuracy: 0.9286 - precision: 0.9711 - recall: 0.8992 - val_loss: 0.1821 - val_accuracy: 0.9309 - val_precision: 0.9903 - val_recall: 0.8977

# %%
inception_resnet2_preds = inception_resnet2.predict_classes(transfer_data_array)
evaluation(transfer_class_list, inception_resnet2_preds)

train_loss = inception_resnet2_history.history['loss']
train_acc = inception_resnet2_history.history['accuracy']
val_loss = inception_resnet2_history.history['val_loss']
val_acc = inception_resnet2_history.history['val_accuracy']


fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,5))
sns.lineplot(inception_resnet2_history.epoch, train_loss, ax=ax1, label='train_loss')
sns.lineplot(inception_resnet2_history.epoch, train_acc, ax=ax2, label='train_accuracy')

sns.lineplot(inception_resnet2_history.epoch, val_loss, ax=ax1, label='val_loss')
sns.lineplot(inception_resnet2_history.epoch, val_acc, ax=ax2, label='val_accuracy')

acc = inception_resnet2.evaluate_generator(transfer_test_data, steps=len(transfer_test_data), verbose=1)
list(zip(inception_resnet2.metrics_names, acc))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.96      0.84      0.90       232
#    PNEUMONIA       0.83      0.96      0.89       195
#
#     accuracy                           0.89       427
#    macro avg       0.90      0.90      0.89       427
# weighted avg       0.90      0.89      0.89       427
#
# Accurancy:  0.8946135831381733
# 14/14 [==============================] - 5s 378ms/step - loss: 0.2944 - accuracy: 0.8946 - precision: 0.8348 - recall: 0.9590
# [('loss', 0.29443687200546265),
#  ('accuracy', 0.8946135640144348),
#  ('precision', 0.8348214030265808),
#  ('recall', 0.9589743614196777)]

# %%
fpr, tpr, thresholds = roc_curve(transfer_class_list, inception_resnet2_preds)
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, linestyle='-', label='InceptionResNetV2')
#plt.plot(fpr, tpr, marker='.')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.xlim(0,1, 20)
plt.ylim(0,1,30)
# show the legend
plt.legend()
# show the plot
plt.show()
print(roc_auc)
# Out:
# 0.8997458001768347

# %%
base_model_inception_res.trainable = True
print('Number of layers in the base model: ', len(base_model_inception_res.layers))

fine_tune = 600
for layer in base_model_inception_res.layers[: fine_tune]:
    layer.trainable = False
# Out:
# Number of layers in the base model:  780

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint('best_model', save_best_only=True)
c_back = tf.keras.callbacks.EarlyStopping(patience=12, restore_best_weights=True)

# %%
inception_resnet2.compile(optimizer='Adam',
              loss='binary_crossentropy',
              metrics=METRICS)

epochs = 20
batch_size=32

steps_per_epoch = transfer_train_data.n // batch_size

inception_resnet2_history = inception_resnet2.fit(transfer_train_data, class_weight=class_weight,
                  steps_per_epoch = steps_per_epoch,
                  epochs=epochs,
                  workers=4,
                  validation_data=transfer_val_data)
# Out:
# Epoch 1/20
# 80/80 [==============================] - 48s 604ms/step - loss: 0.1136 - accuracy: 0.9578 - precision: 0.9748 - recall: 0.9438 - val_loss: 0.1670 - val_accuracy: 0.9382 - val_precision: 0.9904 - val_recall: 0.9094
# Epoch 2/20
# 80/80 [==============================] - 47s 587ms/step - loss: 0.1219 - accuracy: 0.9610 - precision: 0.9761 - recall: 0.9534 - val_loss: 0.1447 - val_accuracy: 0.9473 - val_precision: 0.9906 - val_recall: 0.9240
# Epoch 3/20
# 80/80 [==============================] - 47s 592ms/step - loss: 0.1184 - accuracy: 0.9578 - precision: 0.9746 - recall: 0.9492 - val_loss: 0.2094 - val_accuracy: 0.9200 - val_precision: 0.9901 - val_recall: 0.8801
# Epoch 4/20
# 80/80 [==============================] - 47s 588ms/step - loss: 0.1150 - accuracy: 0.9554 - precision: 0.9725 - recall: 0.9471 - val_loss: 0.1673 - val_accuracy: 0.9345 - val_precision: 0.9935 - val_recall: 0.9006
# Epoch 5/20
# 80/80 [==============================] - 48s 595ms/step - loss: 0.1013 - accuracy: 0.9618 - precision: 0.9804 - recall: 0.9508 - val_loss: 0.1383 - val_accuracy: 0.9418 - val_precision: 0.9874 - val_recall: 0.9181
# Epoch 6/20
# 80/80 [==============================] - 49s 607ms/step - loss: 0.1088 - accuracy: 0.9566 - precision: 0.9745 - recall: 0.9470 - val_loss: 0.1908 - val_accuracy: 0.9273 - val_precision: 0.9967 - val_recall: 0.8860
# Epoch 7/20
# 80/80 [==============================] - 47s 589ms/step - loss: 0.1062 - accuracy: 0.9598 - precision: 0.9789 - recall: 0.9486 - val_loss: 0.1797 - val_accuracy: 0.9327 - val_precision: 0.9935 - val_recall: 0.8977
# Epoch 8/20
# 80/80 [==============================] - 46s 577ms/step - loss: 0.1234 - accuracy: 0.9554 - precision: 0.9711 - recall: 0.9486 - val_loss: 0.1663 - val_accuracy: 0.9455 - val_precision: 0.9937 - val_recall: 0.9181
# Epoch 9/20
# 80/80 [==============================] - 45s 559ms/step - loss: 0.1211 - accuracy: 0.9550 - precision: 0.9710 - recall: 0.9476 - val_loss: 0.1655 - val_accuracy: 0.9418 - val_precision: 0.9936 - val_recall: 0.9123
# Epoch 10/20
# 80/80 [==============================] - 45s 558ms/step - loss: 0.1021 - accuracy: 0.9594 - precision: 0.9796 - recall: 0.9471 - val_loss: 0.2102 - val_accuracy: 0.9200 - val_precision: 0.9967 - val_recall: 0.8743
# Epoch 11/20
# 80/80 [==============================] - 45s 569ms/step - loss: 0.1237 - accuracy: 0.9523 - precision: 0.9723 - recall: 0.9415 - val_loss: 0.2818 - val_accuracy: 0.8891 - val_precision: 1.0000 - val_recall: 0.8216
# Epoch 12/20
# 80/80 [==============================] - 47s 591ms/step - loss: 0.1109 - accuracy: 0.9566 - precision: 0.9759 - recall: 0.9456 - val_loss: 0.2995 - val_accuracy: 0.8800 - val_precision: 1.0000 - val_recall: 0.8070
# Epoch 13/20
# 80/80 [==============================] - 47s 587ms/step - loss: 0.1335 - accuracy: 0.9550 - precision: 0.9726 - recall: 0.9466 - val_loss: 0.1562 - val_accuracy: 0.9418 - val_precision: 0.9905 - val_recall: 0.9152
# Epoch 14/20
# 80/80 [==============================] - 47s 585ms/step - loss: 0.1398 - accuracy: 0.9499 - precision: 0.9750 - recall: 0.9344 - val_loss: 0.1644 - val_accuracy: 0.9364 - val_precision: 0.9904 - val_recall: 0.9064
# Epoch 15/20
# 80/80 [==============================] - 48s 595ms/step - loss: 0.1060 - accuracy: 0.9562 - precision: 0.9788 - recall: 0.9423 - val_loss: 0.1868 - val_accuracy: 0.9200 - val_precision: 0.9901 - val_recall: 0.8801
# Epoch 16/20
# 80/80 [==============================] - 48s 597ms/step - loss: 0.1140 - accuracy: 0.9582 - precision: 0.9747 - recall: 0.9499 - val_loss: 0.1757 - val_accuracy: 0.9291 - val_precision: 0.9903 - val_recall: 0.8947
# Epoch 17/20
# 80/80 [==============================] - 47s 586ms/step - loss: 0.1123 - accuracy: 0.9574 - precision: 0.9767 - recall: 0.9464 - val_loss: 0.2745 - val_accuracy: 0.8873 - val_precision: 1.0000 - val_recall: 0.8187
# Epoch 18/20
# 80/80 [==============================] - 48s 596ms/step - loss: 0.1033 - accuracy: 0.9598 - precision: 0.9775 - recall: 0.9498 - val_loss: 0.1643 - val_accuracy: 0.9364 - val_precision: 0.9904 - val_recall: 0.9064
# Epoch 19/20
# 80/80 [==============================] - 47s 588ms/step - loss: 0.0973 - accuracy: 0.9618 - precision: 0.9762 - recall: 0.9548 - val_loss: 0.1568 - val_accuracy: 0.9418 - val_precision: 0.9905 - val_recall: 0.9152
# Epoch 20/20
# 80/80 [==============================] - 47s 593ms/step - loss: 0.1157 - accuracy: 0.9582 - precision: 0.9760 - recall: 0.9483 - val_loss: 0.1642 - val_accuracy: 0.9345 - val_precision: 0.9904 - val_recall: 0.9035

# %%
inception_resnet2_preds = inception_resnet2.predict_classes(transfer_data_array)
evaluation(transfer_class_list, inception_resnet2_preds)

train_loss = inception_resnet2_history.history['loss']
train_acc = inception_resnet2_history.history['accuracy']
val_loss = inception_resnet2_history.history['val_loss']
val_acc = inception_resnet2_history.history['val_accuracy']


fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,5))
sns.lineplot(inception_resnet2_history.epoch, train_loss, ax=ax1, label='train_loss')
sns.lineplot(inception_resnet2_history.epoch, train_acc, ax=ax2, label='train_accuracy')

sns.lineplot(inception_resnet2_history.epoch, val_loss, ax=ax1, label='val_loss')
sns.lineplot(inception_resnet2_history.epoch, val_acc, ax=ax2, label='val_accuracy')

acc = inception_resnet2.evaluate_generator(transfer_test_data, steps=len(transfer_test_data), verbose=1)
list(zip(inception_resnet2.metrics_names, acc))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.97      0.85      0.91       232
#    PNEUMONIA       0.85      0.96      0.90       195
#
#     accuracy                           0.90       427
#    macro avg       0.91      0.91      0.90       427
# weighted avg       0.91      0.90      0.90       427
#
# Recall:  0.9641025641025641
# ROC-AUC: 0.8997458001768347
# 14/14 [==============================] - 5s 386ms/step - loss: 0.2996 - accuracy: 0.9040 - precision: 0.8468 - recall: 0.9641
# [('loss', 0.2995607852935791),
#  ('accuracy', 0.9039812684059143),
#  ('precision', 0.8468468189239502),
#  ('recall', 0.964102566242218)]

# %% [markdown]
# #### Same model but increasing shear and zoom range for training images

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./225,
                                                               shear_range=0.3,
                                                               zoom_range=0.4,
                                                               horizontal_flip=True)
val_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./225)
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./225)
transfer_train_data = train_datagen.flow_from_directory('../data/chest_xray2/train_2/',
                                               target_size=(100,100),
                                               batch_size=32,
                                               class_mode='binary')
transfer_val_data = val_datagen.flow_from_directory('../data/chest_xray2/val/',
                                               target_size=(100,100),
                                               batch_size=32,
                                               class_mode='binary')
transfer_test_data = test_datagen.flow_from_directory('../data/chest_xray/test/',
                                             target_size=(100,100),
                                             batch_size=32,
                                             class_mode='binary')
# Out:
# Found 2568 images belonging to 2 classes.
# Found 550 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
transfer_first_batch = transfer_test_data.next()
transfer_data_list = transfer_first_batch[0]
batch_index = 0
transfer_class_list = transfer_first_batch[1]
while batch_index <= transfer_test_data.batch_index:
    transfer_data = transfer_test_data.next()
    #print(data[0].shape)
    transfer_data_list=np.concatenate((transfer_data_list, transfer_data[0]))
    transfer_class_list=np.concatenate((transfer_class_list, transfer_data[1]))
    batch_index = batch_index + 1
transfer_data_array = np.asarray(transfer_data_list)
transfer_data_array.shape
# Out:
# (624, 100, 100, 3)

# %%
inception_resnet2_preds = inception_resnet2.predict_classes(transfer_data_array)
evaluation(transfer_class_list, inception_resnet2_preds)

train_loss = inception_resnet2_history.history['loss']
train_acc = inception_resnet2_history.history['accuracy']
val_loss = inception_resnet2_history.history['val_loss']
val_acc = inception_resnet2_history.history['val_accuracy']


fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,5))
sns.lineplot(inception_resnet2_history.epoch, train_loss, ax=ax1, label='train_loss')
sns.lineplot(inception_resnet2_history.epoch, train_acc, ax=ax2, label='train_accuracy')

sns.lineplot(inception_resnet2_history.epoch, val_loss, ax=ax1, label='val_loss')
sns.lineplot(inception_resnet2_history.epoch, val_acc, ax=ax2, label='val_accuracy')

acc = inception_resnet2.evaluate_generator(transfer_test_data, steps=len(transfer_test_data), verbose=1)
list(zip(inception_resnet2.metrics_names, acc))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.95      0.85      0.90       234
#    PNEUMONIA       0.92      0.97      0.95       390
#
#     accuracy                           0.93       624
#    macro avg       0.94      0.91      0.92       624
# weighted avg       0.93      0.93      0.93       624
#
# Recall:  0.9743589743589743
# ROC-AUC: 0.8997458001768347
# 20/20 [==============================] - 6s 318ms/step - loss: 0.2197 - accuracy: 0.9295 - precision: 0.9179 - recall: 0.9744
# [('loss', 0.21972163021564484),
#  ('accuracy', 0.9294871687889099),
#  ('precision', 0.9178743958473206),
#  ('recall', 0.9743589758872986)]
